# %% [markdown]
# ### Multi Camera Fusion

# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt

import matplotlib.patches as patches
from PIL import Image

# %%
files = 'C://users/cathx/repos/squeezedet/squeezedet-pytorch/data/argo'

# %%
train_img = os.path.join(files, 'training/image_2')
train_label = os.path.join(files, 'training/label_2')

# %%
testid = '000001'

# %%
# open the image:
imagef = os.path.join(train_img, testid+'.png')

# %%
image = cv2.imread(imagef)

# %%
cv2.imshow('img', image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
for b in range(len(boxes)):
#     print(b)
    img = cv2.rectangle(image, (boxes[b][0], boxes[b][1]), (boxes[b][2], boxes[b][3]), color= (255,200,0), thickness=1)
# Out:
# <ipython-input-58-64d64c56c0cd>:3: DeprecationWarning: an integer is required (got type numpy.float32).  Implicit conversion to integers using __int__ is deprecated, and may be removed in a future version of Python.
#   img = cv2.rectangle(image, (boxes[b][0], boxes[b][1]), (boxes[b][2], boxes[b][3]), color= (255,200,0), thickness=1)

# %%
cv2.imshow('img', img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img = cv2.rectangle(image, (boxes[3][0], boxes[3][1]), (boxes[3][2], boxes[3][3]), color = (255,0,0), thickness=1)

cv2.imshow('img', img)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <ipython-input-46-3ec98206f28a>:1: DeprecationWarning: an integer is required (got type numpy.float32).  Implicit conversion to integers using __int__ is deprecated, and may be removed in a future version of Python.
#   img = cv2.rectangle(image, (boxes[3][0], boxes[3][1]), (boxes[3][2], boxes[3][3]), color = (255,0,0), thickness=1)

# %%
plt.imshow(image)

# %%
im = Image.open(imagef)

fig, ax = plt.subplots()
ax.imshow(im)

# %%
rect = patches.Rectangle((boxes[3][0], boxes[3][1]), w, h, linewidth = 1, edgecolor='r', facecolor='none')
ax.add_patch(rect)
plt.show()

# %%
# to get w, h:
w = boxes[3][2] - boxes[3][0]
w
# Out:
# 61.0

# %%
h = boxes[3][3] - boxes[3][1]
h
# Out:
# 54.0

# %%
rect = patches.Rectangle((boxes[3][0], boxes[3][1]), w, h, linewidth = 1)

# %%
labelf = os.path.join(train_label, testid+'.txt')

# %%
with open(labelf, 'r') as fp:
    labels = fp.readlines()

# %%
labs = [ann.strip().split(' ') for ann in labels]

# %%
classes, boxes = [], []
for ann  in labs:
    classes.append(ann[0])
    boxes.append([float(x) for x in ann[4:8]])
    
clases = np.array(classes)
boxes = np.array(boxes, dtype=np.float32)

# %%
# classes, boxes

# %%
labels
# Out:
# ['PEDESTRIAN 0 0 0.06 1248 603 1272 657 1.76 0.72 0.75 9.28 0.85 45.349999999999994 1.43 ',
#  'PEDESTRIAN 0 0 -0.07 1150 600 1172 657 1.93 0.69 0.65 6.19 0.81 46.69499999999999 1.37 ',
#  'PEDESTRIAN 0 0 -2.94 1189 601 1213 656 1.87 0.73 0.65 7.61 0.83 46.945 -1.52 ',
#  'VEHICLE 0 0 -3.14 942 609 1003 663 1.49 1.74 4.08 -0.24 0.9 40.675000000000004 -1.56 ',
#  'PEDESTRIAN 0 0 -0.46 279 607 352 742 2.0 0.76 0.76 -10.08 1.05 20.13 1.56 ',
#  'PEDESTRIAN 0 0 -0.4 442 617 491 728 1.86 0.6 0.65 -8.74 1.14 22.77 1.53 ',
#  'PEDESTRIAN 0 0 -2.9 1300 596 1324 659 1.94 0.6 0.65 10.37 0.72 42.54 -1.56 ',
#  'VEHICLE 0 0 -2.75 1312 619 1842 934 1.6 1.74 4.08 3.64 0.93 8.58 -1.55 ',
#  'VEHICLE 0 0 -2.9 1188 621 1460 798 1.51 1.75 4.08 3.38 0.96 13.715 -1.56 ',
#  'VEHICLE 0 0 -2.96 1122 602 1294 736 1.8 1.8 4.08 3.29 0.88 19.96 -1.55 ',
#  'VEHICLE 0 0 -2.98 1099 612 1221 698 1.56 1.74 4.08 3.5 0.94 26.959999999999997 -1.53 ',
# ...
